# %%
# !pip install transformers[sentencepiece] --quiet
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu132 --quiet

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9598046541213989}]

# %%
# We can also pass a list of strings
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598046541213989},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %% [markdown]
# ### Zero-shot Classification

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445957899093628, 0.11197653412818909, 0.043427687138319016]}

# %% [markdown]
# ### Text Generation

# %%
generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to use various tools, such as the command line, to manipulate files, files, and directories efficiently. This is a crucial skill for any computer user.\n\nIn this course, we will cover the following topics:\n\n* Command-line interface (CLI)\n* File manipulation\n* File permissions\n* Directory management\n* Regular expressions\n* Parser functions\n* Command line tools\n* Shell scripting\n* File system management\n* File system utilities\n* Command line utilities\n* Command line interfaces\n* Command line programming\n* Command line programming (re)development\n\nAnd much more!\n\nYou will learn how to use the command line to manipulate files, files, and directories efficiently. You will learn how to use various tools, such as the command line, to manipulate files, files, and directories efficiently.\n\nIn this course, we will cover the following topics:\n\n* Command-line interface (CLI)\n* File management\n* File permissions\n* Directory management\n* Regular expressions\n* Parser functions\n* Command line tools\n* Shell scripting\n* File system management\n* File system utilities\n* Command line utilities\n* Command line interfaces\n* Command line programming\n* Command line programming (re'},
#  {'generated_text': 'In this course, we will teach you how to create and run your own programs in Java using the JDK. We will do it step-by-step, making sure you understand each concept thoroughly.\n\nThe Java language is a very powerful programming language with a rich set of libraries. These libraries allow you to perform complex tasks in a simple way. For example, you can create database connections, manage files, and send emails.\n\nIn this course, we will also teach you how to use the Java platform, which is the foundation of the Java language. We will explain how to install and use the Java Virtual Machine (JVM), which is the software that runs Java programs.\n\nJava is also a great language for developing Web applications, which are programs that run on the Internet. We will go over how to develop Web applications in Java using the JDK and the Java libraries.\n\nIn addition to these topics, we will also introduce you to the Java language syntax, which is the language rules for writing Java programs. We will explain the key concepts in Java such as classes, objects, and variables.\n\nWe will also explain how to use the Java compiler and the Java interpreter to run your programs. Finally, we will introduce you to Java concepts such as inheritance, polymorphism, and abstraction'}]

# %% [markdown]
# ### Mask filler

# %%
unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# [transformers] RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.weight | UNEXPECTED |  |
# roberta.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [{'score': 0.19619818031787872,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.0405271090567112,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %% [markdown]
# ### Named entity recognition

# %%
ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")

# %% [markdown]
# ### Question Answering

# %%
question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)

# %% [markdown]
# ### Summarization

# %%
summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)

# %% [markdown]
# ### Translation

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")

# %% [markdown]
# ### Image and audio pipelines

# %%
image_classifier = pipeline(
    task="image-classification", model="google/vit-base-patch16-224"
)
result = image_classifier(
    "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/pipeline-cat-chonk.jpeg"
)
print(result)

# %% [markdown]
# ### Automatic speech recognition

# %%
transcriber = pipeline(
    task="automatic-speech-recognition", model="openai/whisper-large-v3"
)
result = transcriber(
    "https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac"
)
print(result)
